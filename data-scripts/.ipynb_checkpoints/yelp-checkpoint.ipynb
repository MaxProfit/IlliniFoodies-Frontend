# %%
from requests import get
import pandas as pd
import json


API_KEY = json.load(open("../../../Documents/api_keys.json", "r"))["yelp"]


response = get("https://api.yelp.com/v3/businesses/search",
                headers={"Authorization": "Bearer " + API_KEY},
                params={"location": "Champaign"})
print(response.url)

if response:
    df = pd.DataFrame.from_dict(response.json()["businesses"], orient="columns")
    topPicks = df.nlargest(16, columns=["rating"])
    display(topPicks)
    json.dump(topPicks[["name", "image_url", "url", "rating"]].to_dict(orient="records"), open("../react-app/src/data/topPicks.json", "w"))
else:
    print("NOT FOUND")
# Out:
# https://api.yelp.com/v3/businesses/search?location=Champaign
#                         id                                              alias  \
# 0   VIJ2KiDKhUVhhpNylEIfog                      maize-mexican-grill-champaign
# 1   t_yiQnxUDdPPCN2z4QyezA  golden-harbor-authentic-chinese-cuisine-champaign
# 2   -zEpEmDfFQL-ph0N3BDlXA                               sakanaya-champaign-2
# 4   9MnbQg7kfb_WgxoV0hXKSQ               black-dog-smoke-and-ale-house-urbana
# 9   m6nLTIrEJHtHSYJjVavnzw    kohinoor-indian-restaurant-and-lounge-champaign
# 10  9V4AGrJphOIw2RC1UoPPRw               caribbean-grill-restaurant-champaign
# 13  0FrYsoVHheQGoXEQsH2d2Q                               aroma-cafe-champaign
# 3   -fiUXzkxRfbHY9TKWwuptw        destihl-restaurant-and-brew-works-champaign
# 5   pMiz7SP82Tknv1NbVqoSfg            black-dog-smoke-and-ale-house-champaign
# 6   BKLWat64KRYzsT2DgY6Xxg                   jarlings-custard-cup-champaign-4
# 7   L2c-qKZWumCmOCR-dqBLrg                             seven-saints-champaign
# 8   kNtToQSP_Y5U8tznLXuCaw                   farrens-pub-and-eatery-champaign
# 11  dIZcPB3CtNjMn4O_p8QFxw                   original-pancake-house-champaign
# 12  hvPPw19VdGRsOEkxgyD7tg                               thara-thai-champaign
# 14  l4x5FFzfiCFrGN0S-uZbBQ                   nando-milano-trattoria-champaign
# 15  tZT_0yAeFxuihVnGXoCbWQ                    the-blind-pig-company-champaign
# 16  e0prCZXtHGQIKeQ_wTW3uw                              cafe-kopi-champaign-3
# 17  boIILzBqhjWhq4G0BsB5_A                                   miga-champaign-2
#
#                                        name  \
# 0                       Maize Mexican Grill
# 1   Golden Harbor Authentic Chinese Cuisine
# 2                                  Sakanaya
# 4               Black Dog Smoke & Ale House
# 9     Kohinoor Indian Restaurant and Lounge
# 10               Caribbean Grill Restaurant
# 13                               Aroma Cafe
# 3           DESTIHL Restaurant & Brew Works
# 5               Black Dog Smoke & Ale House
# 6                     Jarling's Custard Cup
# 7                              Seven Saints
# 8                     Farren's Pub & Eatery
# 11                   Original Pancake House
# 12                               Thara Thai
# 14                   Nando Milano Trattoria
# 15                    The Blind Pig Company
# 16                                Cafe Kopi
# 17                                     Miga
#
#                                             image_url  is_closed  \
# 0   https://s3-media2.fl.yelpcdn.com/bphoto/odzcRj...      False
# 1   https://s3-media3.fl.yelpcdn.com/bphoto/wpb6dG...      False
# 2   https://s3-media2.fl.yelpcdn.com/bphoto/cHogr6...      False
# 4   https://s3-media1.fl.yelpcdn.com/bphoto/lJOnFc...      False
# 9   https://s3-media4.fl.yelpcdn.com/bphoto/dKSNvm...      False
# 10  https://s3-media1.fl.yelpcdn.com/bphoto/GNtYJ0...      False
# 13  https://s3-media3.fl.yelpcdn.com/bphoto/d0gFdE...      False
# 3   https://s3-media4.fl.yelpcdn.com/bphoto/itAKUS...      False
# 5   https://s3-media3.fl.yelpcdn.com/bphoto/4b5reQ...      False
# 6   https://s3-media1.fl.yelpcdn.com/bphoto/1CFdSd...      False
# 7   https://s3-media1.fl.yelpcdn.com/bphoto/OQkuCX...      False
# 8   https://s3-media2.fl.yelpcdn.com/bphoto/coqqQB...      False
# 11  https://s3-media1.fl.yelpcdn.com/bphoto/JweY0w...      False
# 12  https://s3-media4.fl.yelpcdn.com/bphoto/Il_L5s...      False
# 14  https://s3-media3.fl.yelpcdn.com/bphoto/YZeqt-...      False
# 15  https://s3-media2.fl.yelpcdn.com/bphoto/l9FUb4...      False
# 16  https://s3-media2.fl.yelpcdn.com/bphoto/4iTxbA...      False
# 17  https://s3-media1.fl.yelpcdn.com/bphoto/VKLL1D...      False
#
#                                                   url  review_count  \
# 0   https://www.yelp.com/biz/maize-mexican-grill-c...           562
# 1   https://www.yelp.com/biz/golden-harbor-authent...           429
# 2   https://www.yelp.com/biz/sakanaya-champaign-2?...           447
# 4   https://www.yelp.com/biz/black-dog-smoke-and-a...           830
# 9   https://www.yelp.com/biz/kohinoor-indian-resta...           187
# 10  https://www.yelp.com/biz/caribbean-grill-resta...            98
# 13  https://www.yelp.com/biz/aroma-cafe-champaign?...           149
# 3   https://www.yelp.com/biz/destihl-restaurant-an...           712
# 5   https://www.yelp.com/biz/black-dog-smoke-and-a...           350
# 6   https://www.yelp.com/biz/jarlings-custard-cup-...           250
# 7   https://www.yelp.com/biz/seven-saints-champaig...           365
# 8   https://www.yelp.com/biz/farrens-pub-and-eater...           294
# 11  https://www.yelp.com/biz/original-pancake-hous...           226
# 12  https://www.yelp.com/biz/thara-thai-champaign?...           213
# 14  https://www.yelp.com/biz/nando-milano-trattori...           222
# 15  https://www.yelp.com/biz/the-blind-pig-company...           188
# 16  https://www.yelp.com/biz/cafe-kopi-champaign-3...           181
# 17  https://www.yelp.com/biz/miga-champaign-2?adju...           183
#
#                                            categories  rating  \
# 0          [{'alias': 'mexican', 'title': 'Mexican'}]     4.5
# 1   [{'alias': 'chinese', 'title': 'Chinese'}, {'a...     4.5
# 2   [{'alias': 'japanese', 'title': 'Japanese'}, {...     4.5
# 4   [{'alias': 'bbq', 'title': 'Barbeque'}, {'alia...     4.5
# 9   [{'alias': 'indpak', 'title': 'Indian'}, {'ali...     4.5
# 10  [{'alias': 'caribbean', 'title': 'Caribbean'},...     4.5
# 13  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...     4.5
# 3   [{'alias': 'newamerican', 'title': 'American (...     4.0
# 5   [{'alias': 'bbq', 'title': 'Barbeque'}, {'alia...     4.0
# 6   [{'alias': 'icecream', 'title': 'Ice Cream & F...     4.0
# 7   [{'alias': 'tradamerican', 'title': 'American ...     4.0
# 8                [{'alias': 'pubs', 'title': 'Pubs'}]     4.0
# 11  [{'alias': 'breakfast_brunch', 'title': 'Break...     4.0
# 12  [{'alias': 'thai', 'title': 'Thai'}, {'alias':...     4.0
# 14         [{'alias': 'italian', 'title': 'Italian'}]     4.0
# 15  [{'alias': 'pubs', 'title': 'Pubs'}, {'alias':...     4.0
# 16  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...     4.0
# 17  [{'alias': 'japanese', 'title': 'Japanese'}, {...     4.0
#
#                                           coordinates  \
# 0      {'latitude': 40.11037, 'longitude': -88.23891}
# 1       {'latitude': 40.11127, 'longitude': -88.2443}
# 2      {'latitude': 40.11001, 'longitude': -88.23307}
# 4   {'latitude': 40.113818215463, 'longitude': -88...
# 9   {'latitude': 40.1212553299844, 'longitude': -8...
# 10   {'latitude': 40.087699, 'longitude': -88.247455}
# 13  {'latitude': 40.117075, 'longitude': -88.2433851}
# 3   {'latitude': 40.1183372538282, 'longitude': -8...
# 5    {'latitude': 40.117978, 'longitude': -88.240271}
# 6   {'latitude': 40.0979551, 'longitude': -88.2469...
# 7   {'latitude': 40.1165558776, 'longitude': -88.2...
# 8   {'latitude': 40.1170512, 'longitude': -88.2426...
# 11    {'latitude': 40.11246, 'longitude': -88.278196}
# 12   {'latitude': 40.133725, 'longitude': -88.260627}
# 14  {'latitude': 40.1175541430712, 'longitude': -8...
# 15  {'latitude': 40.116985629963, 'longitude': -88...
# 16     {'latitude': 40.11682, 'longitude': -88.24271}
# 17     {'latitude': 40.11877, 'longitude': -88.24381}
#
#                                   transactions price  \
# 0                                           []     $
# 1                                           []    $$
# 2                                           []    $$
# 4                                           []    $$
# 9                           [delivery, pickup]    $$
# 10                          [delivery, pickup]     $
# 13                                          []     $
# 3   [delivery, pickup, restaurant_reservation]    $$
# 5                                     [pickup]    $$
# 6                           [delivery, pickup]     $
# 7                                           []    $$
# 8                                   [delivery]    $$
# 11                          [delivery, pickup]    $$
# 12                                          []    $$
# 14                    [restaurant_reservation]   $$$
# 15                                          []    $$
# 16                          [delivery, pickup]     $
# 17                                          []   $$$
#
#                                              location         phone  \
# 0   {'address1': '60 E Green Street', 'address2': ...  +12173556400
# 1   {'address1': '505 S Neil St', 'address2': None...  +12173988988
# 2   {'address1': '403 E Green St', 'address2': Non...  +12173441400
# 4   {'address1': '201 N Broadway Ave', 'address2':...  +12173449334
# 9   {'address1': '6 E Columbia Ave', 'address2': '...  +12175521384
# 10  {'address1': '2135 S Neil St', 'address2': '',...  +12179605375
# 13  {'address1': '118 N Neil St', 'address2': '', ...  +12173563200
# 3   {'address1': '301 N Neil St', 'address2': None...  +12173560301
# 5   {'address1': '320 N Chestnut St', 'address2': ...  +12173449334
# 6   {'address1': '309 W Kirby Ave', 'address2': ''...  +12173522273
# 7   {'address1': '32 E Chester St', 'address2': ''...  +12173517775
# 8   {'address1': '117 N Walnut', 'address2': '', '...  +12173596977
# 11  {'address1': '1909 W Springfield Ave', 'addres...  +12173528866
# 12  {'address1': '912 1/2 W Bloomington Rd', 'addr...  +12173781986
# 14  {'address1': '204 N Neil St', 'address2': '', ...  +12179541439
# 15  {'address1': '120 N Walnut St', 'address2': No...  +12173981532
# 16  {'address1': '109 N Walnut St', 'address2': ''...  +12173594266
# 17  {'address1': '301 N Neil St', 'address2': 'Ste...  +12173981020
#
#      display_phone     distance
# 0   (217) 355-6400  1212.265330
# 1   (217) 398-8988  1016.992210
# 2   (217) 344-1400  1602.580942
# 4   (217) 344-9334  3728.215717
# 9   (217) 552-1384  2129.076871
# 10  (217) 960-5375  1675.241831
# 13  (217) 356-3200  1670.281186
# 3   (217) 356-0301  1794.141981
# 5   (217) 344-9334  1854.247088
# 6   (217) 352-2273   566.393544
# 7   (217) 351-7775  1651.411521
# 8   (217) 359-6977  1684.878249
# 11  (217) 352-8866  2704.932645
# 12  (217) 378-1986  3585.818706
# 14  (217) 954-1439  1721.547443
# 15  (217) 398-1532  1688.041288
# 16  (217) 359-4266  1656.666523
# 17  (217) 398-1020  1853.434863
