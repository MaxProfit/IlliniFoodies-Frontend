# %%
from requests import get
import pandas as pd
import json


API_KEY = json.load(open("../../../Documents/api_keys.json", "r"))["yelp"]

def mapPrice(row):
    if row["price"] == "$":
        return [0, 10]
    elif row["price"] == "$$":
        return [11, 30]
    elif row["price"] == "$$$":
        return [31, 60]
    else:
        return [61, 100]
        

def parseCategories(categories):
    tags = ""
    for obj in categories:
        tags += obj["alias"] + ","
    return tags[:len(tags) - 1]

COLUMNS = ["id", "name", "phone", "address", "image_url", "avgPrice", "rating", "url", "keywords"]
restaurants = []
for offset in [0, 50]:
    response = get("https://api.yelp.com/v3/businesses/search",
                headers={"Authorization": "Bearer " + API_KEY},
                params={"location": "Urbana-Champaign", "limit": 50, "offset": offset})

    if response:
        df = pd.DataFrame.from_dict(response.json()["businesses"], orient="columns")
    
        # clean up some of the data formats
        df["address"] = df["location"].apply(lambda x: x["address1"])
        df[["priceMin", "priceMax"]] = df.apply(mapPrice, axis=1, result_type="expand")
        df["avgPrice"] = df.apply(lambda x: (x["priceMin"] + x["priceMax"]) / 2, axis=1)

        # parse categories into an array of tags
        df["keywords"] = df["categories"].apply(parseCategories)

        # get only the columns we need
        df = df[COLUMNS]
        
        restaurants.append(df)
            
(restaurants[0].append(restaurants[1], ignore_index=True)).to_dict(orient="records")
# Out:
# [{'id': 'VIJ2KiDKhUVhhpNylEIfog',
#   'name': 'Maize Mexican Grill',
#   'phone': '+12173556400',
#   'address': '60 E Green Street',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/odzcRje-W-CGqyV8NbLYkg/o.jpg',
#   'avgPrice': 5.0,
#   'rating': 4.5,
#   'url': 'https://www.yelp.com/biz/maize-mexican-grill-champaign?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'mexican'},
#  {'id': 't_yiQnxUDdPPCN2z4QyezA',
#   'name': 'Golden Harbor Authentic Chinese Cuisine',
#   'phone': '+12173988988',
#   'address': '505 S Neil St',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/wpb6dG94-ECAdzF2z1OYkA/o.jpg',
#   'avgPrice': 20.5,
#   'rating': 4.5,
#   'url': 'https://www.yelp.com/biz/golden-harbor-authentic-chinese-cuisine-champaign?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'chinese,taiwanese'},
#  {'id': '9MnbQg7kfb_WgxoV0hXKSQ',
#   'name': 'Black Dog Smoke & Ale House',
#   'phone': '+12173449334',
#   'address': '201 N Broadway Ave',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/lJOnFchw-mzW6H5IdKh8Zg/o.jpg',
#   'avgPrice': 20.5,
#   'rating': 4.5,
#   'url': 'https://www.yelp.com/biz/black-dog-smoke-and-ale-house-urbana?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'bbq,tradamerican'},
#  {'id': '-zEpEmDfFQL-ph0N3BDlXA',
#   'name': 'Sakanaya Restaurant',
#   'phone': '+12173441400',
#   'address': '403 E Green St',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/cHogr6eHY3Jd8lgM27j_uA/o.jpg',
#   'avgPrice': 20.5,
#   'rating': 4.5,
#   'url': 'https://www.yelp.com/biz/sakanaya-champaign-2?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'japanese,sushi'},
#  {'id': 'BKLWat64KRYzsT2DgY6Xxg',
#   'name': "Jarling's Custard Cup",
#   'phone': '+12173522273',
#   'address': '309 W Kirby Ave',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/1CFdSdDWcEPU9bHdoZhFEA/o.jpg',
#   'avgPrice': 5.0,
#   'rating': 4.0,
#   'url': 'https://www.yelp.com/biz/jarlings-custard-cup-champaign-4?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'icecream'},
#  {'id': '-fiUXzkxRfbHY9TKWwuptw',
#   'name': 'DESTIHL Restaurant & Brew Works',
#   'phone': '+12173560301',
#   'address': '301 N Neil St',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/itAKUSMr9tD13qhtAJI6GQ/o.jpg',
#   'avgPrice': 20.5,
#   'rating': 4.0,
#   'url': 'https://www.yelp.com/biz/destihl-restaurant-and-brew-works-champaign?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'newamerican,brewpubs'},
#  {'id': 'L2c-qKZWumCmOCR-dqBLrg',
#   'name': 'Seven Saints',
#   'phone': '+12173517775',
#   'address': '32 E Chester St',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/OQkuCXRZaKHs_mM8lh3GWA/o.jpg',
#   'avgPrice': 20.5,
#   'rating': 4.0,
#   'url': 'https://www.yelp.com/biz/seven-saints-champaign?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'tradamerican,pubs,lounges'},
#  {'id': 'pMiz7SP82Tknv1NbVqoSfg',
#   'name': 'Black Dog Smoke & Ale House',
#   'phone': '+12173449334',
#   'address': '320 N Chestnut St',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/4b5reQvrRdyEmF8eWLfQXQ/o.jpg',
#   'avgPrice': 20.5,
#   'rating': 4.0,
#   'url': 'https://www.yelp.com/biz/black-dog-smoke-and-ale-house-champaign?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'bbq,bars'},
#  {'id': '9V4AGrJphOIw2RC1UoPPRw',
#   'name': 'Caribbean Grill Restaurant',
#   'phone': '+12179605375',
#   'address': '2135 S Neil St',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/GNtYJ0qtgEAV-_U9gf9spQ/o.jpg',
#   'avgPrice': 5.0,
#   'rating': 4.5,
#   'url': 'https://www.yelp.com/biz/caribbean-grill-restaurant-champaign?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'caribbean,desserts'},
#  {'id': 'kNtToQSP_Y5U8tznLXuCaw',
#   'name': "Farren's Pub & Eatery",
#   'phone': '+12173596977',
#   'address': '117 N Walnut',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/coqqQBuSe-E-ss0I7RcX8w/o.jpg',
#   'avgPrice': 20.5,
#   'rating': 4.0,
#   'url': 'https://www.yelp.com/biz/farrens-pub-and-eatery-champaign?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'pubs'},
#  {'id': 'th4pZ5LkoIIkb1Vmu_m2DA',
#   'name': 'Meatheads',
#   'phone': '+12173525555',
#   'address': '1305 S Neil St',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/KfUeGgRvjTBsQVLPFqeozg/o.jpg',
#   'avgPrice': 20.5,
#   'rating': 4.0,
#   'url': 'https://www.yelp.com/biz/meatheads-champaign?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'burgers'},
#  {'id': 'u8C8pRvaHXg3PgDrsUHJHQ',
#   'name': "Papa Del's Pizza",
#   'phone': '+12173597700',
#   'address': '1201 S Neil St',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/n-PRhtPVlZH4hBJ5kWhpqA/o.jpg',
#   'avgPrice': 20.5,
#   'rating': 3.5,
#   'url': 'https://www.yelp.com/biz/papa-dels-pizza-champaign-4?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'pizza,salad,sandwiches'},
#  {'id': 'm6nLTIrEJHtHSYJjVavnzw',
#   'name': 'Kohinoor Indian Restaurant and Lounge',
#   'phone': '+12175521384',
#   'address': '6 E Columbia Ave',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/dKSNvmx0DobnMsqznuP0zA/o.jpg',
#   'avgPrice': 20.5,
#   'rating': 4.5,
#   'url': 'https://www.yelp.com/biz/kohinoor-indian-restaurant-and-lounge-champaign?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'indpak,bars'},
#  {'id': '0FrYsoVHheQGoXEQsH2d2Q',
#   'name': 'Aroma Cafe',
#   'phone': '+12173563200',
#   'address': '118 N Neil St',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/d0gFdEiHuRI6zktBaAyigw/o.jpg',
#   'avgPrice': 5.0,
#   'rating': 4.5,
#   'url': 'https://www.yelp.com/biz/aroma-cafe-champaign?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'coffee,cafes'},
#  {'id': 'tZT_0yAeFxuihVnGXoCbWQ',
#   'name': 'The Blind Pig Company',
#   'phone': '+12173981532',
#   'address': '120 N Walnut St',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/l9FUb4-z0fGQQF2uzUbPDw/o.jpg',
#   'avgPrice': 20.5,
#   'rating': 4.0,
#   'url': 'https://www.yelp.com/biz/the-blind-pig-company-champaign?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'pubs,beer_and_wine'},
#  {'id': 'l4x5FFzfiCFrGN0S-uZbBQ',
#   'name': 'Nando Milano Trattoria',
#   'phone': '+12179541439',
#   'address': '204 N Neil St',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/YZeqt-SBX6fBuJ-Xg0vXBg/o.jpg',
#   'avgPrice': 45.5,
#   'rating': 4.0,
#   'url': 'https://www.yelp.com/biz/nando-milano-trattoria-champaign?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'italian'},
#  {'id': 'dIZcPB3CtNjMn4O_p8QFxw',
#   'name': 'Original Pancake House',
#   'phone': '+12173528866',
#   'address': '1909 W Springfield Ave',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/JweY0wnelPWIr-2UgNPD9g/o.jpg',
#   'avgPrice': 20.5,
#   'rating': 4.0,
#   'url': 'https://www.yelp.com/biz/original-pancake-house-champaign?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'breakfast_brunch'},
#  {'id': '4hWDMVtfnpyY72_5QMbthA',
#   'name': 'Old Time Meat & Deli Shoppe',
#   'phone': '+12173519123',
#   'address': '2018 S Neil St',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/qRT2S0lAclFBDwxLpzrDRg/o.jpg',
#   'avgPrice': 20.5,
#   'rating': 5.0,
#   'url': 'https://www.yelp.com/biz/old-time-meat-and-deli-shoppe-champaign?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'meats,delis'},
#  {'id': '5_cn7M-9swHrFbnqZtYGBQ',
#   'name': 'Bangkok Thai and Pho 911',
#   'phone': '+12179541641',
#   'address': '410 E Green St',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/2o0Y7b2EjVNPfU3no3L2Hw/o.jpg',
#   'avgPrice': 5.0,
#   'rating': 4.0,
#   'url': 'https://www.yelp.com/biz/bangkok-thai-and-pho-911-champaign?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'thai'},
#  {'id': 'e0prCZXtHGQIKeQ_wTW3uw',
#   'name': 'Cafe Kopi',
#   'phone': '+12173594266',
#   'address': '109 N Walnut St',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4iTxbA3FyOvo-M_BaNQHXQ/o.jpg',
#   'avgPrice': 5.0,
#   'rating': 4.0,
#   'url': 'https://www.yelp.com/biz/cafe-kopi-champaign-3?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'coffee,desserts,sandwiches'},
#  {'id': 'ovApUucCKSb9k0lTP2JieQ',
#   'name': 'Huaraches Moroleon',
#   'phone': '+12173446772',
#   'address': '805 Philo Rd',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/1WFwREfQwOG1QV2mzH3Bdg/o.jpg',
#   'avgPrice': 5.0,
#   'rating': 4.5,
#   'url': 'https://www.yelp.com/biz/huaraches-moroleon-urbana?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'mexican'},
#  {'id': 'o13eH93qmWVNFZogkjhd9w',
#   'name': 'Courier Cafe',
#   'phone': '+12173281811',
#   'address': '111 N Race St',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/n3MEYq0UV5fzNZ8yLzzqtQ/o.jpg',
#   'avgPrice': 5.0,
#   'rating': 4.0,
#   'url': 'https://www.yelp.com/biz/courier-cafe-urbana?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'breakfast_brunch,cafes,burgers'},
#  {'id': 'gnqHyA6gY2-m9S-FKt6Xqw',
#   'name': 'Cravings',
#   'phone': '+12173282538',
#   'address': '603 S Wright St',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/chY5KM74iiXjZwSWxbYQAQ/o.jpg',
#   'avgPrice': 5.0,
#   'rating': 4.0,
#   'url': 'https://www.yelp.com/biz/cravings-champaign-2?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'chinese,panasian'},
#  {'id': 'boIILzBqhjWhq4G0BsB5_A',
#   'name': 'Miga',
#   'phone': '+12173981020',
#   'address': '301 N Neil St',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/VKLL1DTAvRoMgUQLvR-21A/o.jpg',
#   'avgPrice': 45.5,
#   'rating': 4.0,
#   'url': 'https://www.yelp.com/biz/miga-champaign-2?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'japanese,newamerican,sushi'},
#  {'id': 'S_9OaE_RBWBIXnUKvxJKsQ',
#   'name': "Watson's Shack & Rail",
#   'phone': '+12176070168',
#   'address': '211 N Neil St',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/-uI51DjqjNFTzSi86wUQQw/o.jpg',
#   'avgPrice': 20.5,
#   'rating': 4.0,
#   'url': 'https://www.yelp.com/biz/watsons-shack-and-rail-champaign?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'bars,tradamerican'},
#  {'id': '6ockUmdOBYBApEsUCJkBzA',
#   'name': 'El Oasis',
#   'phone': '+12179540215',
#   'address': '510 N Cunningham Ave',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/P_4y9YbxU_Rj04AJePl-7w/o.jpg',
#   'avgPrice': 5.0,
#   'rating': 4.5,
#   'url': 'https://www.yelp.com/biz/el-oasis-urbana?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'icecream,mexican'},
#  {'id': 'xWGn7oqLOZu_00H8pZOtsQ',
#   'name': 'Cracked on Green',
#   'phone': '+12179540361',
#   'address': '619 E Green St',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/lUz5NPQS7KWpIgZV-gjkXQ/o.jpg',
#   'avgPrice': 5.0,
#   'rating': 4.0,
#   'url': 'https://www.yelp.com/biz/cracked-on-green-champaign?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'coffee,breakfast_brunch,foodtrucks'},
#  {'id': 'SvxSoyZn0WW0c7bFLIYfMA',
#   'name': "Baxter's American Grille",
#   'phone': '+12172399299',
#   'address': '100 Trade Centre Dr',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/sAq6iGCZZ-Obko5eCslZnQ/o.jpg',
#   'avgPrice': 20.5,
#   'rating': 4.0,
#   'url': 'https://www.yelp.com/biz/baxters-american-grille-champaign?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'tradamerican,steak,bars'},
#  {'id': 'dn9lwYUxmhs_mLKPu7L25Q',
#   'name': 'Big Grove Tavern',
#   'phone': '+12172393505',
#   'address': '1 E Main St',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ARpnH81GWzbvbnqKkOjvgA/o.jpg',
#   'avgPrice': 20.5,
#   'rating': 3.5,
#   'url': 'https://www.yelp.com/biz/big-grove-tavern-champaign?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'newamerican,pubs,breakfast_brunch'},
#  {'id': 'hvPPw19VdGRsOEkxgyD7tg',
#   'name': 'Thara Thai',
#   'phone': '+12173781986',
#   'address': '912 1/2 W Bloomington Rd',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Il_L5s_aVZ7ScDl7uuuNeg/o.jpg',
#   'avgPrice': 20.5,
#   'rating': 4.0,
#   'url': 'https://www.yelp.com/biz/thara-thai-champaign?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'thai,salad,noodles'},
#  {'id': 'qeJnMI5RmyJ2TZvkqvjn6Q',
#   'name': "Biaggi's Ristorante Italiano",
#   'phone': '+12173564300',
#   'address': '2235 S Neil St',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ISiYezRLxOPIwNVpScqaog/o.jpg',
#   'avgPrice': 20.5,
#   'rating': 3.5,
#   'url': 'https://www.yelp.com/biz/biaggis-ristorante-italiano-champaign-2?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'italian'},
#  {'id': '5lw5rrhFMz-liykUn8dGSw',
#   'name': "Fernando's Food",
#   'phone': '+12172550210',
#   'address': '44 E Sprinfield',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/s6neDI4X_Pnn5ZSohVWWNA/o.jpg',
#   'avgPrice': 5.0,
#   'rating': 5.0,
#   'url': 'https://www.yelp.com/biz/fernandos-food-champaign?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'foodtrucks,mexican'},
#  {'id': 'Ah4i15g8Ow_zphzcpulTxQ',
#   'name': 'The Bread Company',
#   'phone': '+12173831007',
#   'address': '706 S Goodwin Ave',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/rAFy2zIImv6YBY6wdyyyXg/o.jpg',
#   'avgPrice': 20.5,
#   'rating': 4.0,
#   'url': 'https://www.yelp.com/biz/the-bread-company-urbana?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'bakeries,sandwiches,modern_european'},
#  {'id': 'LyGab6ITDEMDI5E0YcC0Ng',
#   'name': 'The Himalayan Chimney',
#   'phone': '+12175521834',
#   'address': '134 W Church St',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/4pTJ5iXex2XvC8qKAplavQ/o.jpg',
#   'avgPrice': 20.5,
#   'rating': 4.0,
#   'url': 'https://www.yelp.com/biz/the-himalayan-chimney-champaign?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'indpak,bars'},
#  {'id': 'jKxES7iLV63H_PfyGVGIDw',
#   'name': 'Lai Lai Wok',
#   'phone': '+12173281888',
#   'address': '402 E Green St',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/d8e_eSI0tUrMhtWpfdCbTw/o.jpg',
#   'avgPrice': 20.5,
#   'rating': 4.0,
#   'url': 'https://www.yelp.com/biz/lai-lai-wok-champaign?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'chinese'},
#  {'id': 'kKCwp86xU9XKRnAALQDhrw',
#   'name': 'The Red Herring Vegetarian Restaurant',
#   'phone': '+12173672340',
#   'address': '1209 W Oregon St',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Ah-3T8MAMK3Jcmf3hqn3rg/o.jpg',
#   'avgPrice': 5.0,
#   'rating': 4.5,
#   'url': 'https://www.yelp.com/biz/the-red-herring-vegetarian-restaurant-urbana-2?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'vegetarian,cafes,vegan'},
#  {'id': 'NEVA0IYbawceL6kz5v5DAw',
#   'name': 'Kofusion',
#   'phone': '+12175311166',
#   'address': '1 E Main St',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/0485F6RM9NpsAyE0FCmk-g/o.jpg',
#   'avgPrice': 20.5,
#   'rating': 3.5,
#   'url': 'https://www.yelp.com/biz/kofusion-champaign?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'asianfusion,sushi'},
#  {'id': 'X57f6FWZiwI1wOidPPhOrQ',
#   'name': 'Dos Reales',
#   'phone': '+12173516879',
#   'address': '1407 N Prospect Ave',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/2dmHSXyaHQfYGdgsl4kO2A/o.jpg',
#   'avgPrice': 5.0,
#   'rating': 4.0,
#   'url': 'https://www.yelp.com/biz/dos-reales-champaign?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'mexican'},
#  {'id': 'CrIWqmuO2uQWwl3z11K_BA',
#   'name': 'Pizzeria Antica',
#   'phone': '+12175304137',
#   'address': '10 E Chester St',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/qGUcOx65tVtE9gk252JuKw/o.jpg',
#   'avgPrice': 20.5,
#   'rating': 4.0,
#   'url': 'https://www.yelp.com/biz/pizzeria-antica-champaign?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'pizza,italian'},
#  {'id': 'UmZdQID7QJoyg2R92mK3HA',
#   'name': 'Siam Terrace',
#   'phone': '+12173678424',
#   'address': '212 W Main St',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/I7wfV0QAOD2CWfQGDjzSMw/o.jpg',
#   'avgPrice': 20.5,
#   'rating': 4.0,
#   'url': 'https://www.yelp.com/biz/siam-terrace-urbana?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'thai'},
#  {'id': 'O3zVw-VAcJi8ta4B6v5iAA',
#   'name': 'Sun Singer Wine and Spirits',
#   'phone': '+12173511115',
#   'address': '1115 W Windsor Rd',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/6cauFpgZliLn5fBV8qqZYA/o.jpg',
#   'avgPrice': 20.5,
#   'rating': 4.0,
#   'url': 'https://www.yelp.com/biz/sun-singer-wine-and-spirits-champaign?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'beer_and_wine,delis,wine_bars'},
#  {'id': 'DkwuiCqvSrqE8fUA4qJPBw',
#   'name': 'Everyday Kitchen Restaurant & Bar',
#   'phone': '+12176071960',
#   'address': '1807 S Neil St',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/M-1GfWaQ3f6z2BlAgnrZUg/o.jpg',
#   'avgPrice': 20.5,
#   'rating': 4.5,
#   'url': 'https://www.yelp.com/biz/everyday-kitchen-restaurant-and-bar-champaign?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'tradamerican,cocktailbars'},
#  {'id': 'SgG5E7PUrCIsEMP0BVSlTg',
#   'name': 'Cheese and Crackers',
#   'phone': '+12176158531',
#   'address': '1715 W Kirby',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/kiSnogZSAYN_PnKf3UmRbw/o.jpg',
#   'avgPrice': 20.5,
#   'rating': 4.0,
#   'url': 'https://www.yelp.com/biz/cheese-and-crackers-champaign?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'chocolate,delis,seafoodmarkets'},
#  {'id': 'dNch89PUCbxvhieKmWi8LQ',
#   'name': 'Cocomero',
#   'phone': '+12173283888',
#   'address': '709 S Wright St',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/EFE3DGgEK24Auh6Na9hMUQ/o.jpg',
#   'avgPrice': 5.0,
#   'rating': 4.0,
#   'url': 'https://www.yelp.com/biz/cocomero-champaign?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'icecream,bubbletea,desserts'},
#  {'id': 'D6SCh4BwNb52wZIqXdS4JQ',
#   'name': 'Esquire Lounge',
#   'phone': '+12173985858',
#   'address': '106 N Walnut St',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/cqp6ZCBNajrHmqvB_6HV_Q/o.jpg',
#   'avgPrice': 5.0,
#   'rating': 4.0,
#   'url': 'https://www.yelp.com/biz/esquire-lounge-champaign?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'pizza,poolhalls,tradamerican'},
#  {'id': 'RnGG5bAz4nTPo_Ui99Kzbg',
#   'name': 'Le Peep Restaurant',
#   'phone': '+12173527599',
#   'address': '2209 S Neil St',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/GPdF3ow9xeKrYjMpA7lM4A/o.jpg',
#   'avgPrice': 20.5,
#   'rating': 3.5,
#   'url': 'https://www.yelp.com/biz/le-peep-restaurant-champaign?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'breakfast_brunch,coffee,tradamerican'},
#  {'id': 'Gvox18F9QxsSS9qG2O8E-A',
#   'name': "Sam's Cafe",
#   'phone': '+12173527102',
#   'address': '115 N Walnut St',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/PJ2b2O2_9hCeWP00pjIrPw/o.jpg',
#   'avgPrice': 5.0,
#   'rating': 4.0,
#   'url': 'https://www.yelp.com/biz/sams-cafe-champaign?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'diners,breakfast_brunch'},
#  {'id': 'FsnwQwatA43aeGhJlxQ_Kg',
#   'name': 'Paris Super Crepes',
#   'phone': '+12176071404',
#   'address': '601 S 6th St',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/E7CUH3Rx8G42BJRQTXJeUQ/o.jpg',
#   'avgPrice': 5.0,
#   'rating': 4.5,
#   'url': 'https://www.yelp.com/biz/paris-super-crepes-champaign?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'desserts,icecream,creperies'},
#  {'id': '0-WocGTpO3Zm4q1Zzz49Rw',
#   'name': 'Sushi Kame',
#   'phone': '+12173563366',
#   'address': '132 W Church St',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/hNm9jXKyZyR6ZGQmHDA7nQ/o.jpg',
#   'avgPrice': 20.5,
#   'rating': 3.5,
#   'url': 'https://www.yelp.com/biz/sushi-kame-champaign?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'sushi,japanese'},
#  {'id': '8mKV3KThn3wXGL3OVxrCNg',
#   'name': 'Sitara',
#   'phone': '+12176070378',
#   'address': '114 S Race St',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/kZohRVXT1912k82J5vJ7zg/o.jpg',
#   'avgPrice': 20.5,
#   'rating': 4.0,
#   'url': 'https://www.yelp.com/biz/sitara-urbana?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'indpak,vegetarian'},
#  {'id': 'MfJSKP5HRllfts13MiKs1g',
#   'name': 'Flying Machine Avionics',
#   'phone': '',
#   'address': '202 S 1st St',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/uZ-eyb19lIfvtmCv4fs1hA/o.jpg',
#   'avgPrice': 5.0,
#   'rating': 4.5,
#   'url': 'https://www.yelp.com/biz/flying-machine-avionics-champaign?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'coffee'},
#  {'id': 'J2mmkwPiTQg3aCXP3afiJQ',
#   'name': 'Sticky Rice',
#   'phone': '+12179541929',
#   'address': '415 N Neil St',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/esoJhsANawKVTFfV-5iJGQ/o.jpg',
#   'avgPrice': 5.0,
#   'rating': 4.5,
#   'url': 'https://www.yelp.com/biz/sticky-rice-champaign?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'laotian,thai,noodles'},
#  {'id': 'HAgPykErkXpPJlwOHbY01Q',
#   'name': "J Gumbo's",
#   'phone': '+12173374840',
#   'address': '700 S Gregory St',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/eCfRm1zxDxnUKKDmkSRR7Q/o.jpg',
#   'avgPrice': 5.0,
#   'rating': 4.0,
#   'url': 'https://www.yelp.com/biz/j-gumbos-urbana?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'cajun'},
#  {'id': 'vCopginiBsz1STNhQPb8XA',
#   'name': 'The Dancing Dog Eatery & Juicery',
#   'phone': '+12175521344',
#   'address': '126 W Main St',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Sb4N0zIuNdicVDHVsL8YZg/o.jpg',
#   'avgPrice': 20.5,
#   'rating': 4.0,
#   'url': 'https://www.yelp.com/biz/the-dancing-dog-eatery-and-juicery-urbana?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'vegan,juicebars,sandwiches'},
#  {'id': 'B9W60PTxn7XOZfk4BiTvyw',
#   'name': 'BrewLab Coffee',
#   'phone': '+12179797123',
#   'address': '630 S 5th St',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/HxZs1hUWBwzB7iptyG7BMA/o.jpg',
#   'avgPrice': 20.5,
#   'rating': 4.5,
#   'url': 'https://www.yelp.com/biz/brewlab-coffee-champaign?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'coffee'},
#  {'id': 'Pz2mK5ZkmiWiHZG0OUcKdw',
#   'name': "Rick's Bakery",
#   'phone': '+12173449383',
#   'address': '124 W Main St',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/_7GnFBjiRcKMgstwenqOkA/o.jpg',
#   'avgPrice': 20.5,
#   'rating': 4.5,
#   'url': 'https://www.yelp.com/biz/ricks-bakery-urbana?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'bakeries'},
#  {'id': 'QdganL5AW9E_fNoRVroLig',
#   'name': 'Golden Wok',
#   'phone': '+12173568383',
#   'address': '405 E University Ave',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/hMkIW3LwkWcjbzuWPnbZVg/o.jpg',
#   'avgPrice': 5.0,
#   'rating': 4.0,
#   'url': 'https://www.yelp.com/biz/golden-wok-champaign?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'thai,chinese'},
#  {'id': 'iZleRh4SOtf4GquA5L8WXw',
#   'name': 'Crane Alley',
#   'phone': '+12173847526',
#   'address': '115 W Main St',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/vtl1fGPy7AAjOIBQ798pPg/o.jpg',
#   'avgPrice': 20.5,
#   'rating': 4.0,
#   'url': 'https://www.yelp.com/biz/crane-alley-urbana?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'bars,tradamerican'},
#  {'id': 'miMx3VNOW8qPJC5wEGaIOw',
#   'name': 'Xinh Xinh Cafe',
#   'phone': '+12173377600',
#   'address': '114 N Vine St',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/29ir72vsI94XbFhcuM5GoQ/o.jpg',
#   'avgPrice': 5.0,
#   'rating': 4.0,
#   'url': 'https://www.yelp.com/biz/xinh-xinh-cafe-urbana-2?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'vietnamese'},
#  {'id': 'a3hjBPsnpcTpcquQXLeS0w',
#   'name': 'Dragon Fire Pizza',
#   'phone': '+12176492433',
#   'address': None,
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/G7TrGejGYO1auYcRfx5XOA/o.jpg',
#   'avgPrice': 5.0,
#   'rating': 4.5,
#   'url': 'https://www.yelp.com/biz/dragon-fire-pizza-champaign?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'foodtrucks,pizza'},
#  {'id': 'a39B-BfbCipNkNH7vwCfug',
#   'name': 'Mid-Summer Lounge',
#   'phone': '+12176071434',
#   'address': '623 E Green St',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/zTOFyEFlmUK9wleJboCRkA/o.jpg',
#   'avgPrice': 5.0,
#   'rating': 4.0,
#   'url': 'https://www.yelp.com/biz/mid-summer-lounge-champaign?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'chinese,asianfusion,noodles'},
#  {'id': 'oD1PPb-TfMIkkg77u1zCAw',
#   'name': 'Salad Meister',
#   'phone': '+12178409456',
#   'address': '601 S 6th St',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/1Gh2VcRS1nRJef5_8jIFqw/o.jpg',
#   'avgPrice': 5.0,
#   'rating': 4.5,
#   'url': 'https://www.yelp.com/biz/salad-meister-champaign?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'salad,wraps'},
#  {'id': 'rXIDrS8Rz8r09vH4gjHfGQ',
#   'name': "Manolo's Pizza & Empanadas",
#   'phone': '+12173650110',
#   'address': '1115 W Oregon St',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/D6IS-LzaLk7NoaLztn_uXQ/o.jpg',
#   'avgPrice': 5.0,
#   'rating': 4.0,
#   'url': 'https://www.yelp.com/biz/manolos-pizza-and-empanadas-urbana?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'pizza,empanadas'},
#  {'id': 'dtKy808TwAgtOcwSCbXFJw',
#   'name': 'Jipbap Taste of Korea',
#   'phone': '',
#   'address': '601 S 6th St',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/FsV99DzMt_nhiCGXbVvL_g/o.jpg',
#   'avgPrice': 5.0,
#   'rating': 4.0,
#   'url': 'https://www.yelp.com/biz/jipbap-taste-of-korea-champaign?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'korean'},
#  {'id': 'Z7r_FJXEyfyvVsyv2y7gFQ',
#   'name': 'Cactus Grill',
#   'phone': '+12173518226',
#   'address': '1405 S Neil St',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/kKdQ49-93hgaosWzGYSmmQ/o.jpg',
#   'avgPrice': 5.0,
#   'rating': 4.0,
#   'url': 'https://www.yelp.com/biz/cactus-grill-champaign?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'tex-mex,mexican'},
#  {'id': 'PTQVaWA-I5ZLzwy5oBbVMg',
#   'name': 'Pekara Bakery and Bistro',
#   'phone': '+12173594500',
#   'address': '116 N Neil St',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/CwPRGPxjyRCLvGCvc-Xobg/o.jpg',
#   'avgPrice': 5.0,
#   'rating': 3.5,
#   'url': 'https://www.yelp.com/biz/pekara-bakery-and-bistro-champaign?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'creperies,sandwiches,gelato'},
#  {'id': 'tqxS-gA5zhBvdI5lk7kDGg',
#   'name': 'Maize at the Station',
#   'phone': '+12173553611',
#   'address': '100 N Chestnut St',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/hejRMzETRXJ7pzJz_CTSlQ/o.jpg',
#   'avgPrice': 5.0,
#   'rating': 4.0,
#   'url': 'https://www.yelp.com/biz/maize-at-the-station-champaign-3?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'mexican'},
#  {'id': 'zswdqM8Av3KxVv9o7_6ORA',
#   'name': 'Rainbow Garden Champaign',
#   'phone': '+12175772341',
#   'address': '1402 S Neil St',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/9OeYrFOORvHb2e0JhKGy4w/o.jpg',
#   'avgPrice': 20.5,
#   'rating': 3.5,
#   'url': 'https://www.yelp.com/biz/rainbow-garden-champaign-champaign?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'chinese'},
#  {'id': 'C_Zj7H7bUJ5kGCwFmEwW6w',
#   'name': 'B Won',
#   'phone': '+12173522966',
#   'address': '2006 S Neil St',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/66fMi8L8zFfgjixiUkz5_Q/o.jpg',
#   'avgPrice': 20.5,
#   'rating': 3.5,
#   'url': 'https://www.yelp.com/biz/b-won-champaign?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'korean'},
#  {'id': 'Epr8Ft7LwYAzotFwxQX6uw',
#   'name': 'Latea Bubble Tea Lounge',
#   'phone': '+12179541855',
#   'address': '601 S 6th St',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/gYmnpYDeTKn4lL7Q4o-GkA/o.jpg',
#   'avgPrice': 5.0,
#   'rating': 4.0,
#   'url': 'https://www.yelp.com/biz/latea-bubble-tea-lounge-champaign?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'desserts,bubbletea'},
#  {'id': 'DjDcRTH09r1Yma6qd0om0Q',
#   'name': 'Art Mart',
#   'phone': '+12173447979',
#   'address': '1705 S Prospect Ave',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/BwJVdlLrBX9yLJY27DLY5w/o.jpg',
#   'avgPrice': 20.5,
#   'rating': 4.5,
#   'url': 'https://www.yelp.com/biz/art-mart-champaign?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'gourmet,bakeries,womenscloth'},
#  {'id': 'kyXEnWKQGWSThY6EcjORuw',
#   'name': "Zorba's Restaurant",
#   'phone': '+12173440710',
#   'address': '627 E Green St',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/IXd9tiXzlN-YShU_WaTeVg/o.jpg',
#   'avgPrice': 5.0,
#   'rating': 3.5,
#   'url': 'https://www.yelp.com/biz/zorbas-restaurant-champaign?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'mediterranean,greek'},
#  {'id': 'PBmfdx-tC2D54FI3HtcKww',
#   'name': 'The Ribeye',
#   'phone': '+12173519115',
#   'address': '1701 S Neil St',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/vLuBwnCB_zlAaq84dwW9Mw/o.jpg',
#   'avgPrice': 20.5,
#   'rating': 3.5,
#   'url': 'https://www.yelp.com/biz/the-ribeye-champaign?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'steak,salad,venues'},
#  {'id': 'NPpttQPnIbzezRMURx973g',
#   'name': 'Signature Grill',
#   'phone': '+12176070893',
#   'address': '505 E Green St',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/0X0YydehFBQ0h_HPWWpsOQ/o.jpg',
#   'avgPrice': 5.0,
#   'rating': 4.5,
#   'url': 'https://www.yelp.com/biz/signature-grill-champaign-2?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'mediterranean,indpak,mexican'},
#  {'id': 'ODURDhURWmZr6b--O4nt3w',
#   'name': "Jupiter's Pizzeria and Billiards",
#   'phone': '+12173985988',
#   'address': '39 E Main St',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/TBbmnjoqmB81VHNNJFLLUg/o.jpg',
#   'avgPrice': 20.5,
#   'rating': 3.5,
#   'url': 'https://www.yelp.com/biz/jupiters-pizzeria-and-billiards-champaign?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'poolhalls,pizza,lounges'},
#  {'id': 'SUktrYdNQD8k2vvkM4OpfA',
#   'name': 'Peking Garden Restaurant',
#   'phone': '+12173558888',
#   'address': '206 N Randolph St',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/xR39vJ1gpiquW2FZZqCwuw/o.jpg',
#   'avgPrice': 20.5,
#   'rating': 4.0,
#   'url': 'https://www.yelp.com/biz/peking-garden-restaurant-champaign?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'chinese'},
#  {'id': 'ZxQlHVm0pj0ERqpwhEHc6w',
#   'name': 'San Maru',
#   'phone': '+12173522119',
#   'address': '2504 Village Green Pl',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/wAWgEcC5jxNGzQ1Nbvfd-g/o.jpg',
#   'avgPrice': 20.5,
#   'rating': 4.5,
#   'url': 'https://www.yelp.com/biz/san-maru-champaign?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'korean'},
#  {'id': 'mklo4H47YWK7f18YXTCEoA',
#   'name': "Murphy's Pub",
#   'phone': '+12173444372',
#   'address': '604 E Green St',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/WtfY3BE_thsKQGFUxzQtPw/o.jpg',
#   'avgPrice': 5.0,
#   'rating': 3.5,
#   'url': 'https://www.yelp.com/biz/murphys-pub-champaign?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'pubs,newamerican'},
#  {'id': 'yiFcujhdkeDhmXRufMG-lw',
#   'name': 'Masijta Grill',
#   'phone': '+12175521188',
#   'address': '202 N Race',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/CGFwfltBLLvYfdl-wK3S4A/o.jpg',
#   'avgPrice': 20.5,
#   'rating': 4.0,
#   'url': 'https://www.yelp.com/biz/masijta-grill-urbana?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'korean'},
#  {'id': 'oWQwUw8xfQgi1nVNKgS6vA',
#   'name': 'Silvercreek',
#   'phone': '+12173283402',
#   'address': '402 N Race St',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9PuXdR_XINzCaRW5hs7_-g/o.jpg',
#   'avgPrice': 20.5,
#   'rating': 3.5,
#   'url': 'https://www.yelp.com/biz/silvercreek-urbana?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'newamerican,breakfast_brunch,venues'},
#  {'id': 'k441Clzdv9Ia4QZanEne3g',
#   'name': "Wood N' Hog Barbecue",
#   'phone': '+12173671018',
#   'address': '904 N 4th St',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/kzGA1OUO0FxMBz9BQChddg/o.jpg',
#   'avgPrice': 20.5,
#   'rating': 4.5,
#   'url': 'https://www.yelp.com/biz/wood-n-hog-barbecue-champaign-2?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'bbq,chicken_wings'},
#  {'id': 'hP2DOm7E2H4P7MOS7XN_SQ',
#   'name': "Hamilton Walker's",
#   'phone': '+12173500363',
#   'address': '201 N Neil St',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/MYqa6qS_MyNiBYvTB0zRPg/o.jpg',
#   'avgPrice': 45.5,
#   'rating': 3.5,
#   'url': 'https://www.yelp.com/biz/hamilton-walkers-champaign?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'seafood,steak,bars'},
#  {'id': '3I3gl-WS7CBa41A4BDA7yw',
#   'name': 'Broadway Food Hall',
#   'phone': '',
#   'address': '401 N Broadway Ave',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/QKpPr2bshNs1lY5GJy5Uig/o.jpg',
#   'avgPrice': 20.5,
#   'rating': 4.5,
#   'url': 'https://www.yelp.com/biz/broadway-food-hall-urbana-4?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'food_court'},
#  {'id': 'E6QAh8UPRo6Tlg6hkcWCHw',
#   'name': 'Bombay Indian Grill',
#   'phone': '+12173443380',
#   'address': '401 E Green St',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/NHEWHLxfozrPlhny_Xmu3g/o.jpg',
#   'avgPrice': 20.5,
#   'rating': 3.5,
#   'url': 'https://www.yelp.com/biz/bombay-indian-grill-champaign?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'indpak'},
#  {'id': '_a6jhRFIgOe74U73T5B-Ww',
#   'name': 'Fiesta Cafe',
#   'phone': '+12173525902',
#   'address': '216 S 1st St',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/kCLiK04rQSUZQBys_GxsBg/o.jpg',
#   'avgPrice': 20.5,
#   'rating': 3.5,
#   'url': 'https://www.yelp.com/biz/fiesta-cafe-champaign?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'mexican'},
#  {'id': 'BkqM_Ou82P3gn_PTxEN3pw',
#   'name': 'Ozu Ramen',
#   'phone': '',
#   'address': '601 S 6th St',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/SzRWgvK1WHH_HE0jXiGVpA/o.jpg',
#   'avgPrice': 20.5,
#   'rating': 3.5,
#   'url': 'https://www.yelp.com/biz/ozu-ramen-champaign?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'ramen,asianfusion'},
#  {'id': 'Y-rCSbMqXWk54bKRAIoyUQ',
#   'name': 'Caffe Paradiso',
#   'phone': '+12173846066',
#   'address': '801 S Lincoln Ave',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/7sGoWIbPPdqdZV9KITz-Dg/o.jpg',
#   'avgPrice': 5.0,
#   'rating': 3.5,
#   'url': 'https://www.yelp.com/biz/caffe-paradiso-urbana?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'coffee,sandwiches,shavedice'},
#  {'id': 'cDGaMsCAx8guR1IUrxLxWA',
#   'name': 'Pho Cafe',
#   'phone': '+12175521106',
#   'address': '611 E Green St',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5oUpcWbFGby6vDrgrN0YBw/o.jpg',
#   'avgPrice': 5.0,
#   'rating': 4.0,
#   'url': 'https://www.yelp.com/biz/pho-cafe-champaign?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'vietnamese,thai'},
#  {'id': 'BcrFZDyviqw_wF9oQQ5qVA',
#   'name': 'Caffe Bene',
#   'phone': '+12176072611',
#   'address': '524 E Green St',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/EkNNWB3_ULdjx5s5w4BKxQ/o.jpg',
#   'avgPrice': 20.5,
#   'rating': 4.5,
#   'url': 'https://www.yelp.com/biz/caffe-bene-champaign-3?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'coffee'},
#  {'id': '4cPM1Hcj3UiN3fxyOsiR9w',
#   'name': "Li'l Porgy's Bar-B-Que",
#   'phone': '+12173988575',
#   'address': '1917 W Springfield Ave',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/MQGzY79mfO46gLzHZ_r-eA/o.jpg',
#   'avgPrice': 5.0,
#   'rating': 3.5,
#   'url': 'https://www.yelp.com/biz/lil-porgys-bar-b-que-champaign?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'bbq'},
#  {'id': 'wsuzuLD3KV7L8oMinLCI0A',
#   'name': "Merry Ann's Diner",
#   'phone': '+12173525399',
#   'address': '1510 S Neil St',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/cY2w6XHKRF0Oy8IkM6J3kQ/o.jpg',
#   'avgPrice': 5.0,
#   'rating': 3.0,
#   'url': 'https://www.yelp.com/biz/merry-anns-diner-champaign?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'diners,breakfast_brunch,tradamerican'},
#  {'id': 'ECKXHrl2GqNKRMG9jp4trg',
#   'name': 'Good Fella Korean Bistro',
#   'phone': '+12172395959',
#   'address': '905 S Neil St',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/C5smD5_mWZB6jq0vPNZFkA/o.jpg',
#   'avgPrice': 20.5,
#   'rating': 4.0,
#   'url': 'https://www.yelp.com/biz/good-fella-korean-bistro-champaign?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'korean'},
#  {'id': 'UUsS7SrTQQ2AvvpslfrvFA',
#   'name': 'Legends',
#   'phone': '+12173557674',
#   'address': '522 E Green St',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Qa5cc-J0p8Cxf54b-ephRQ/o.jpg',
#   'avgPrice': 5.0,
#   'rating': 3.5,
#   'url': 'https://www.yelp.com/biz/legends-champaign?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'bars,sandwiches'},
#  {'id': 'ZyOgY-z9sHdHp8_FDoQAJg',
#   'name': "Scotty's Brewhouse",
#   'phone': '+12175304394',
#   'address': '2001 S Neil St',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ucK19tOj4ceuii9SBz0MfQ/o.jpg',
#   'avgPrice': 20.5,
#   'rating': 3.0,
#   'url': 'https://www.yelp.com/biz/scottys-brewhouse-champaign?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'sportsbars,burgers,brewpubs'},
#  {'id': 'NSzhahVpI_B32snhJHM0HA',
#   'name': 'Texas Roadhouse',
#   'phone': '+12173559901',
#   'address': '204 N. Country Fair Dr',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/7q9hsSlBKex8g07pe4X2ZQ/o.jpg',
#   'avgPrice': 20.5,
#   'rating': 4.0,
#   'url': 'https://www.yelp.com/biz/texas-roadhouse-champaign?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'steak,bbq,tradamerican'},
#  {'id': 'ZMcbVIEXsLO7j1Q1GXKPSw',
#   'name': 'A-Ri-Rang',
#   'phone': '+12173555569',
#   'address': '607 S Wright St',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/GMtV-l-cmXnSEw43gATzHQ/o.jpg',
#   'avgPrice': 5.0,
#   'rating': 4.0,
#   'url': 'https://www.yelp.com/biz/a-ri-rang-champaign?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'korean'},
#  {'id': '0grgvnq4GgoY-estWytUhg',
#   'name': "Timpone's",
#   'phone': '+12173447619',
#   'address': '710 S Goodwin Ave',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/U2D6GFY7cEwhjjJUyNp6Hw/o.jpg',
#   'avgPrice': 20.5,
#   'rating': 3.5,
#   'url': 'https://www.yelp.com/biz/timpones-urbana?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'italian,steak'},
#  {'id': 'BsxefnHbrpDN7HB2hJrEiw',
#   'name': 'Taco Motorizado',
#   'phone': '+12176371974',
#   'address': '607 N Cunningham Ave',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/HhnMkO03Nv8FpZ9bv2YTnA/o.jpg',
#   'avgPrice': 5.0,
#   'rating': 4.5,
#   'url': 'https://www.yelp.com/biz/taco-motorizado-urbana-4?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'mexican,foodtrucks,vegetarian'},
#  {'id': 'VVkO08qlcTCkCq6t5gLcpw',
#   'name': 'Hopscotch',
#   'phone': '+12176075436',
#   'address': '802 W John St',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/g9-bxg9sbfTqowKFMVSVxg/o.jpg',
#   'avgPrice': 20.5,
#   'rating': 3.5,
#   'url': 'https://www.yelp.com/biz/hopscotch-champaign?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'cupcakes,bakeries,customcakes'},
#  {'id': 'WAAYgXdq-1zdo5Je-pq3kg',
#   'name': "Columbia Street Roastery By Herriott's",
#   'phone': '+12173529713',
#   'address': '24 Columbia St',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/R3GJrgHe9J1WjPphM35ZiA/o.jpg',
#   'avgPrice': 20.5,
#   'rating': 4.5,
#   'url': 'https://www.yelp.com/biz/columbia-street-roastery-by-herriotts-champaign?adjust_creative=wh-q_IKkI9xwpcFki0OEoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wh-q_IKkI9xwpcFki0OEoA',
#   'keywords': 'coffeeroasteries'}]
